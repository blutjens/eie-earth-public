# %%
#Create flood masks for color baseline

#Create Segmentation Masks
#Generate masks for all of the data generated by pix2pixHD_baseline
! cd ../.. ; python src/models/Pix2pix-CycleGAN/test.py --phase "" --dataroot results/flood_color/unconditioned_segmented --direction AtoB --results_dir ./temp/flood_color/ --dataset_mode single --model pix2pix --checkpoints_dir ./pretrained/Pix2pix-CycleGAN/flood_segmentation/scratch_1024_plus/ --name . --num_test 390 --no_flip --gpu_ids -1 --batch_size 1  --load_size 1024 --crop_size 1024
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pretrained/Pix2pix-CycleGAN/flood_segmentation/scratch_1024_plus/	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: results/flood_color/unconditioned_segmented	[default: None]
#              dataset_mode: single                        	[default: aligned]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                isFineTune: False                         	[default: None]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: .                             	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  num_test: 390                           	[default: 50]
#               num_threads: 4
#                 output_nc: 3
#                     phase:                               	[default: test]
#                preprocess: resize_and_crop
#               results_dir: ./temp/flood_color/           	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [SingleDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from ./pretrained/Pix2pix-CycleGAN/flood_segmentation/scratch_1024_plus/./latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.414 M
# -----------------------------------------------
# creating web directory ./temp/flood_color/./_latest
# processing (0000)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000004_pre_disaster_synthesized_image.jpg']
# processing (0005)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000029_pre_disaster_synthesized_image.jpg']
# processing (0010)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000077_pre_disaster_synthesized_image.jpg']
# processing (0015)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000112_pre_disaster_synthesized_image.jpg']
# processing (0020)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000125_pre_disaster_synthesized_image.jpg']
# processing (0025)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000133_pre_disaster_synthesized_image.jpg']
# processing (0030)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000150_pre_disaster_synthesized_image.jpg']
# processing (0035)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000171_pre_disaster_synthesized_image.jpg']
# processing (0040)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000179_pre_disaster_synthesized_image.jpg']
# processing (0045)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000196_pre_disaster_synthesized_image.jpg']
# processing (0050)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000211_pre_disaster_synthesized_image.jpg']
# processing (0055)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000240_pre_disaster_synthesized_image.jpg']
# processing (0060)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000267_pre_disaster_synthesized_image.jpg']
# processing (0065)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000292_pre_disaster_synthesized_image.jpg']
# processing (0070)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000318_pre_disaster_synthesized_image.jpg']
# processing (0075)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000343_pre_disaster_synthesized_image.jpg']
# processing (0080)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000378_pre_disaster_synthesized_image.jpg']
# processing (0085)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000415_pre_disaster_synthesized_image.jpg']
# processing (0090)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000456_pre_disaster_synthesized_image.jpg']
# processing (0095)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000483_pre_disaster_synthesized_image.jpg']
# processing (0100)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000519_pre_disaster_synthesized_image.jpg']
# processing (0105)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-florence_00000541_pre_disaster_synthesized_image.jpg']
# processing (0110)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000018_pre_disaster_synthesized_image.jpg']
# processing (0115)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000044_pre_disaster_synthesized_image.jpg']
# processing (0120)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000068_pre_disaster_synthesized_image.jpg']
# processing (0125)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000103_pre_disaster_synthesized_image.jpg']
# processing (0130)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000127_pre_disaster_synthesized_image.jpg']
# processing (0135)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000143_pre_disaster_synthesized_image.jpg']
# processing (0140)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000163_pre_disaster_synthesized_image.jpg']
# processing (0145)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000182_pre_disaster_synthesized_image.jpg']
# processing (0150)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000202_pre_disaster_synthesized_image.jpg']
# processing (0155)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000230_pre_disaster_synthesized_image.jpg']
# processing (0160)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000259_pre_disaster_synthesized_image.jpg']
# processing (0165)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000297_pre_disaster_synthesized_image.jpg']
# processing (0170)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000305_pre_disaster_synthesized_image.jpg']
# processing (0175)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000326_pre_disaster_synthesized_image.jpg']
# processing (0180)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000341_pre_disaster_synthesized_image.jpg']
# processing (0185)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000364_pre_disaster_synthesized_image.jpg']
# processing (0190)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000390_pre_disaster_synthesized_image.jpg']
# processing (0195)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000420_pre_disaster_synthesized_image.jpg']
# processing (0200)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000453_pre_disaster_synthesized_image.jpg']
# processing (0205)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000465_pre_disaster_synthesized_image.jpg']
# processing (0210)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000483_pre_disaster_synthesized_image.jpg']
# processing (0215)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-harvey_00000516_pre_disaster_synthesized_image.jpg']
# processing (0220)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000022_pre_disaster_synthesized_image.jpg']
# processing (0225)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000037_pre_disaster_synthesized_image.jpg']
# processing (0230)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000101_pre_disaster_synthesized_image.jpg']
# processing (0235)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000113_pre_disaster_synthesized_image.jpg']
# processing (0240)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000122_pre_disaster_synthesized_image.jpg']
# processing (0245)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000160_pre_disaster_synthesized_image.jpg']
# processing (0250)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000184_pre_disaster_synthesized_image.jpg']
# processing (0255)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000236_pre_disaster_synthesized_image.jpg']
# processing (0260)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000272_pre_disaster_synthesized_image.jpg']
# processing (0265)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000291_pre_disaster_synthesized_image.jpg']
# processing (0270)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000318_pre_disaster_synthesized_image.jpg']
# processing (0275)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000340_pre_disaster_synthesized_image.jpg']
# processing (0280)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000358_pre_disaster_synthesized_image.jpg']
# processing (0285)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-matthew_00000394_pre_disaster_synthesized_image.jpg']
# processing (0290)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000018_pre_disaster_synthesized_image.jpg']
# processing (0295)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000032_pre_disaster_synthesized_image.jpg']
# processing (0300)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000071_pre_disaster_synthesized_image.jpg']
# processing (0305)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000091_pre_disaster_synthesized_image.jpg']
# processing (0310)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000113_pre_disaster_synthesized_image.jpg']
# processing (0315)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000129_pre_disaster_synthesized_image.jpg']
# processing (0320)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000163_pre_disaster_synthesized_image.jpg']
# processing (0325)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000179_pre_disaster_synthesized_image.jpg']
# processing (0330)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000198_pre_disaster_synthesized_image.jpg']
# processing (0335)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000254_pre_disaster_synthesized_image.jpg']
# processing (0340)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000277_pre_disaster_synthesized_image.jpg']
# processing (0345)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000327_pre_disaster_synthesized_image.jpg']
# processing (0350)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000366_pre_disaster_synthesized_image.jpg']
# processing (0355)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000378_pre_disaster_synthesized_image.jpg']
# processing (0360)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000397_pre_disaster_synthesized_image.jpg']
# processing (0365)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000420_pre_disaster_synthesized_image.jpg']
# processing (0370)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000436_pre_disaster_synthesized_image.jpg']
# processing (0375)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000468_pre_disaster_synthesized_image.jpg']
# processing (0380)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000507_pre_disaster_synthesized_image.jpg']
# processing (0385)-th image... ['results/flood_color/unconditioned_segmented/test-set_test_images_labels_targets_test_images_hurricane-michael_00000544_pre_disaster_synthesized_image.jpg']

# %%
! cd ../.. ; cp -R temp/flood_color/_latest/images/*fake_B.png results/flood_color/unconditioned_segmented/
