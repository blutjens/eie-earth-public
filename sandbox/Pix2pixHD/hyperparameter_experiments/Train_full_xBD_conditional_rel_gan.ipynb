# %% [markdown]
# # Train

# %%
# !cd ../.. ; python src/models/Pix2pixHD/train.py --use_rel_gan --no_vgg_loss --ngf 80 --ndf 40 --nef 24 --continue_train --niter 100 --niter_decay 100 --checkpoints_dir temp/checkpoint/Pix2pixHD/ --name full_xBD_conditional_binary_relativistic --dataroot xBD_full --dataset_mode physics_aligned_bin --no_instance --label_nc 0 --input_nc 4 --batchSize 1 --gpu_ids 0
# Out:
# ------------ Options -------------
# augmentation_aggressive: False
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: temp/checkpoint/Pix2pixHD/
# continue_train: False
# data_type: 32
# dataroot: xBD_full
# dataset_mode: physics_aligned_bin
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# input_nc: 4
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 0
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# local_rank: 0
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: full_xBD_conditional_binary_relativistic
# ndf: 40
# nef: 24
# netG: global
# ngf: 80
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# no_vgg_loss: True
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# resize_or_crop: scale_width
# save_epoch_freq: 10
# save_latest_freq: 1000
# serial_batches: False
# tf_log: False
# use_dropout: False
# use_rel_gan: True
# verbose: False
# which_epoch: latest
# -------------- End ----------------
# src/models/Pix2pixHD/train.py:9: DeprecationWarning: fractions.gcd() is deprecated. Use math.gcd() instead.
#   def lcm(a,b): return abs(a * b)/fractions.gcd(a,b) if a and b else 0
# CustomDatasetDataLoader
# dataset [AlignedPhysicsBinDataset] was created
# #training images = 2799
# GlobalGenerator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(4, 80, kernel_size=(7, 7), stride=(1, 1))
#     (2): InstanceNorm2d(80, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): ReLU(inplace=True)
#     (4): Conv2d(80, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): InstanceNorm2d(160, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): ReLU(inplace=True)
#     (7): Conv2d(160, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): InstanceNorm2d(320, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(320, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): InstanceNorm2d(640, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (12): ReLU(inplace=True)
#     (13): Conv2d(640, 1280, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (14): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (15): ReLU(inplace=True)
#     (16): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (17): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (18): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (19): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (20): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (21): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (22): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (23): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (24): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(1280, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (25): ConvTranspose2d(1280, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (26): InstanceNorm2d(640, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (27): ReLU(inplace=True)
#     (28): ConvTranspose2d(640, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (29): InstanceNorm2d(320, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (30): ReLU(inplace=True)
#     (31): ConvTranspose2d(320, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (32): InstanceNorm2d(160, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (33): ReLU(inplace=True)
#     (34): ConvTranspose2d(160, 80, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (35): InstanceNorm2d(80, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (36): ReLU(inplace=True)
#     (37): ReflectionPad2d((3, 3, 3, 3))
#     (38): Conv2d(80, 3, kernel_size=(7, 7), stride=(1, 1))
#     (39): Tanh()
#   )
# )
# MultiscaleDiscriminator(
#   (scale0_layer0): Sequential(
#     (0): Conv2d(7, 40, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale0_layer1): Sequential(
#     (0): Conv2d(40, 80, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): InstanceNorm2d(80, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale0_layer2): Sequential(
#     (0): Conv2d(80, 160, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): InstanceNorm2d(160, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale0_layer3): Sequential(
#     (0): Conv2d(160, 320, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): InstanceNorm2d(320, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale0_layer4): Sequential(
#     (0): Conv2d(320, 1, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   )
#   (scale1_layer0): Sequential(
#     (0): Conv2d(7, 40, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale1_layer1): Sequential(
#     (0): Conv2d(40, 80, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): InstanceNorm2d(80, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale1_layer2): Sequential(
#     (0): Conv2d(80, 160, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): InstanceNorm2d(160, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale1_layer3): Sequential(
#     (0): Conv2d(160, 320, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): InstanceNorm2d(320, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale1_layer4): Sequential(
#     (0): Conv2d(320, 1, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   )
#   (downsample): AvgPool2d(kernel_size=3, stride=2, padding=[1, 1])
# )
# create web directory temp/checkpoint/Pix2pixHD/full_xBD_conditional_binary_relativistic/web...
# (epoch: 1, iters: 100, time: 0.738) G_GAN: 2.591 G_GAN_Feat: 8.539 D_real: 5.021 D_fake: 1.806
# (epoch: 1, iters: 200, time: 0.690) G_GAN: 2.704 G_GAN_Feat: 7.207 D_real: 4.624 D_fake: 1.664
# (epoch: 1, iters: 300, time: 0.672) G_GAN: 2.916 G_GAN_Feat: 9.810 D_real: 4.263 D_fake: 1.589
# (epoch: 1, iters: 400, time: 0.637) G_GAN: 2.458 G_GAN_Feat: 12.240 D_real: 5.065 D_fake: 1.762
# (epoch: 1, iters: 500, time: 0.638) G_GAN: 2.316 G_GAN_Feat: 9.786 D_real: 5.380 D_fake: 1.848
# (epoch: 1, iters: 600, time: 0.638) G_GAN: 2.151 G_GAN_Feat: 9.067 D_real: 5.257 D_fake: 1.704
# (epoch: 1, iters: 700, time: 0.638) G_GAN: 2.705 G_GAN_Feat: 7.890 D_real: 4.084 D_fake: 1.394
# (epoch: 1, iters: 800, time: 0.638) G_GAN: 2.289 G_GAN_Feat: 8.002 D_real: 5.197 D_fake: 1.743
# (epoch: 1, iters: 900, time: 0.638) G_GAN: 1.977 G_GAN_Feat: 8.048 D_real: 5.480 D_fake: 1.729
# (epoch: 1, iters: 1000, time: 0.637) G_GAN: 1.891 G_GAN_Feat: 10.989 D_real: 5.681 D_fake: 1.786
# saving the latest model (epoch 1, total_steps 1000)
# (epoch: 1, iters: 1100, time: 0.638) G_GAN: 2.142 G_GAN_Feat: 8.487 D_real: 5.257 D_fake: 1.699
# (epoch: 1, iters: 1200, time: 0.637) G_GAN: 2.408 G_GAN_Feat: 8.829 D_real: 4.575 D_fake: 1.492
# (epoch: 1, iters: 1300, time: 0.638) G_GAN: 1.930 G_GAN_Feat: 8.776 D_real: 5.051 D_fake: 1.491
# (epoch: 1, iters: 1400, time: 0.638) G_GAN: 2.061 G_GAN_Feat: 9.555 D_real: 5.546 D_fake: 1.803
# (epoch: 1, iters: 1500, time: 0.637) G_GAN: 1.701 G_GAN_Feat: 13.943 D_real: 5.673 D_fake: 1.687
# (epoch: 1, iters: 1600, time: 0.637) G_GAN: 2.022 G_GAN_Feat: 8.868 D_real: 5.322 D_fake: 1.672
# (epoch: 1, iters: 1700, time: 0.638) G_GAN: 1.830 G_GAN_Feat: 10.864 D_real: 5.666 D_fake: 1.748
# (epoch: 1, iters: 1800, time: 0.637) G_GAN: 2.779 G_GAN_Feat: 5.830 D_real: 4.000 D_fake: 1.389
# (epoch: 1, iters: 1900, time: 0.638) G_GAN: 2.088 G_GAN_Feat: 9.639 D_real: 5.806 D_fake: 1.947
# (epoch: 1, iters: 2000, time: 0.637) G_GAN: 2.648 G_GAN_Feat: 5.861 D_real: 4.199 D_fake: 1.423
# saving the latest model (epoch 1, total_steps 2000)
# (epoch: 1, iters: 2100, time: 0.637) G_GAN: 1.759 G_GAN_Feat: 11.245 D_real: 5.984 D_fake: 1.872
# (epoch: 1, iters: 2200, time: 0.638) G_GAN: 1.995 G_GAN_Feat: 7.886 D_real: 5.136 D_fake: 1.566
# (epoch: 1, iters: 2300, time: 0.638) G_GAN: 2.161 G_GAN_Feat: 9.225 D_real: 5.083 D_fake: 1.622
# (epoch: 1, iters: 2400, time: 0.638) G_GAN: 1.820 G_GAN_Feat: 9.355 D_real: 5.973 D_fake: 1.897
# (epoch: 1, iters: 2500, time: 0.637) G_GAN: 1.787 G_GAN_Feat: 7.274 D_real: 4.888 D_fake: 1.337
# (epoch: 1, iters: 2600, time: 0.637) G_GAN: 1.695 G_GAN_Feat: 8.760 D_real: 5.854 D_fake: 1.774
# (epoch: 1, iters: 2700, time: 0.637) G_GAN: 1.907 G_GAN_Feat: 10.221 D_real: 5.771 D_fake: 1.839
# End of epoch 1 / 200 	 Time Taken: 1822 sec
# (epoch: 2, iters: 1, time: 0.638) G_GAN: 1.801 G_GAN_Feat: 10.176 D_real: 5.610 D_fake: 1.705
# (epoch: 2, iters: 101, time: 0.638) G_GAN: 1.797 G_GAN_Feat: 8.622 D_real: 5.685 D_fake: 1.741
# (epoch: 2, iters: 201, time: 0.638) G_GAN: 2.587 G_GAN_Feat: 7.767 D_real: 4.042 D_fake: 1.314
# saving the latest model (epoch 2, total_steps 3000)
# (epoch: 2, iters: 301, time: 0.637) G_GAN: 2.292 G_GAN_Feat: 7.058 D_real: 4.793 D_fake: 1.543
# (epoch: 2, iters: 401, time: 0.638) G_GAN: 1.999 G_GAN_Feat: 9.062 D_real: 5.734 D_fake: 1.866
# (epoch: 2, iters: 501, time: 0.637) G_GAN: 1.995 G_GAN_Feat: 8.084 D_real: 5.258 D_fake: 1.626
# (epoch: 2, iters: 601, time: 0.637) G_GAN: 1.853 G_GAN_Feat: 9.791 D_real: 5.568 D_fake: 1.711
# (epoch: 2, iters: 701, time: 0.637) G_GAN: 1.744 G_GAN_Feat: 8.216 D_real: 5.901 D_fake: 1.822
# (epoch: 2, iters: 801, time: 0.638) G_GAN: 2.525 G_GAN_Feat: 6.568 D_real: 4.193 D_fake: 1.359
# (epoch: 2, iters: 901, time: 0.638) G_GAN: 1.793 G_GAN_Feat: 9.532 D_real: 6.039 D_fake: 1.916
# (epoch: 2, iters: 1001, time: 0.637) G_GAN: 1.816 G_GAN_Feat: 10.011 D_real: 5.636 D_fake: 1.726
# (epoch: 2, iters: 1101, time: 0.638) G_GAN: 1.936 G_GAN_Feat: 8.903 D_real: 5.475 D_fake: 1.706
# (epoch: 2, iters: 1201, time: 0.638) G_GAN: 1.739 G_GAN_Feat: 9.266 D_real: 5.946 D_fake: 1.842
# saving the latest model (epoch 2, total_steps 4000)
# (epoch: 2, iters: 1301, time: 0.636) G_GAN: 2.507 G_GAN_Feat: 7.818 D_real: 4.781 D_fake: 1.644
# (epoch: 2, iters: 1401, time: 0.638) G_GAN: 1.913 G_GAN_Feat: 7.636 D_real: 5.359 D_fake: 1.636
# (epoch: 2, iters: 1501, time: 0.637) G_GAN: 1.852 G_GAN_Feat: 9.118 D_real: 5.345 D_fake: 1.598
# (epoch: 2, iters: 1601, time: 0.638) G_GAN: 1.909 G_GAN_Feat: 9.941 D_real: 5.291 D_fake: 1.600
# (epoch: 2, iters: 1701, time: 0.638) G_GAN: 1.952 G_GAN_Feat: 9.404 D_real: 5.231 D_fake: 1.592
# (epoch: 2, iters: 1801, time: 0.638) G_GAN: 2.002 G_GAN_Feat: 8.949 D_real: 5.233 D_fake: 1.617
# (epoch: 2, iters: 1901, time: 0.638) G_GAN: 1.839 G_GAN_Feat: 9.080 D_real: 5.707 D_fake: 1.773
# (epoch: 2, iters: 2001, time: 0.638) G_GAN: 2.446 G_GAN_Feat: 8.513 D_real: 4.319 D_fake: 1.382
# (epoch: 2, iters: 2101, time: 0.637) G_GAN: 2.338 G_GAN_Feat: 8.786 D_real: 3.903 D_fake: 1.120
# (epoch: 2, iters: 2201, time: 0.637) G_GAN: 2.095 G_GAN_Feat: 10.211 D_real: 5.131 D_fake: 1.613
# saving the latest model (epoch 2, total_steps 5000)
# (epoch: 2, iters: 2301, time: 0.637) G_GAN: 1.938 G_GAN_Feat: 7.734 D_real: 5.626 D_fake: 1.782
# (epoch: 2, iters: 2401, time: 0.638) G_GAN: 1.978 G_GAN_Feat: 8.919 D_real: 5.260 D_fake: 1.619
# (epoch: 2, iters: 2501, time: 0.638) G_GAN: 2.365 G_GAN_Feat: 8.756 D_real: 4.543 D_fake: 1.454
# (epoch: 2, iters: 2601, time: 0.638) G_GAN: 1.792 G_GAN_Feat: 9.936 D_real: 5.784 D_fake: 1.788

# %%
#Generate predictions over the test set. 
# !cd ../.. ; python src/models/Pix2pixHD/test.py --checkpoints_dir temp/checkpoint/Pix2pixHD/  --ngf 64 --ndf 32 --nef 16 --netG local --phase test --how_many 2000 --name conditional_binary_agg --dataroot xBD --dataset_mode physics_aligned_bin --no_instance --label_nc 0 --n_blocks_global 8 --input_nc 4 --gpu_ids 6,7 --results_dir temp/Pix2pixHD/
# Out:
# usage: test.py [-h] [--name NAME] [--gpu_ids GPU_IDS]
#                [--checkpoints_dir CHECKPOINTS_DIR] [--model MODEL]
#                [--norm NORM] [--dataset_mode DATASET_MODE] [--use_dropout]
#                [--data_type {8,16,32}] [--verbose] [--fp16]
#                [--local_rank LOCAL_RANK] [--batchSize BATCHSIZE]
#                [--loadSize LOADSIZE] [--fineSize FINESIZE]
#                [--label_nc LABEL_NC] [--input_nc INPUT_NC]
#                [--output_nc OUTPUT_NC] [--dataroot DATAROOT]
#                [--resize_or_crop RESIZE_OR_CROP] [--serial_batches]
#                [--no_flip] [--nThreads NTHREADS]
#                [--max_dataset_size MAX_DATASET_SIZE]
#                [--augmentation_aggressive] [--display_winsize DISPLAY_WINSIZE]
#                [--tf_log] [--netG NETG] [--ngf NGF]
#                [--n_downsample_global N_DOWNSAMPLE_GLOBAL]
#                [--n_blocks_global N_BLOCKS_GLOBAL]
#                [--n_blocks_local N_BLOCKS_LOCAL]
#                [--n_local_enhancers N_LOCAL_ENHANCERS]
#                [--niter_fix_global NITER_FIX_GLOBAL] [--no_instance]
#                [--instance_feat] [--label_feat] [--feat_num FEAT_NUM]
#                [--load_features] [--n_downsample_E N_DOWNSAMPLE_E] [--nef NEF]
#                [--n_clusters N_CLUSTERS] [--ntest NTEST]
#                [--results_dir RESULTS_DIR] [--aspect_ratio ASPECT_RATIO]
#                [--phase PHASE] [--which_epoch WHICH_EPOCH]
#                [--how_many HOW_MANY] [--cluster_path CLUSTER_PATH]
#                [--use_encoded_image] [--export_onnx EXPORT_ONNX]
#                [--engine ENGINE] [--onnx ONNX] [--slosh_inference]
# test.py: error: unrecognized arguments: --ndf 32

# %% [markdown]
# ### We move things around at the moment in ./Temp/
# The model output is placed into ./temp/ .We use this directory to work, then we carefully selects what goes into ./results/.
# ./temp/ does not get uploaded into our bucket, only ./results/ do!

# %%
# Move synthesized results to a folder to be used by the segmentation network
# !cd ../../temp/Pix2pixHD/conditional_binary_agg/test_latest/ ; mkdir to_segment; cp -R images/*synthesized*.jpg to_segment
# Out:
# /bin/sh: 1: cd: can't cd to ../../temp/Pix2pixHD/conditional_binary_agg/test_latest/
# cp: cannot stat 'images/*synthesized*.jpg': No such file or directory

# %%
#Create Segmentation Masks
#Generate masks for all of the data generated by pix2pixHD_baseline
! cd ../.. ; python src/models/Pix2pix-CycleGAN/test.py --phase to_segment --dataroot temp/Pix2pixHD/conditional_binary_agg/test_latest/ --direction AtoB --results_dir ./temp/Pix2pixHD/conditional_binary_agg_masks --dataset_mode single --model pix2pix --checkpoints_dir ./pretrained/Pix2pix-CycleGAN/flood_segmentation/scratch_1024_plus/ --name . --num_test 2000 --no_flip --gpu_ids 0 --max_dataset_size 2000 --batch_size 1  --load_size 1024 --crop_size 1024
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pretrained/Pix2pix-CycleGAN/flood_segmentation/scratch_1024_plus/	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: temp/Pix2pixHD/conditional_binary_agg/test_latest/	[default: None]
#              dataset_mode: single                        	[default: aligned]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                isFineTune: False                         	[default: None]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: 2000                          	[default: inf]
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: .                             	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  num_test: 2000                          	[default: 50]
#               num_threads: 4
#                 output_nc: 3
#                     phase: to_segment                    	[default: test]
#                preprocess: resize_and_crop
#               results_dir: ./temp/Pix2pixHD/conditional_binary_agg_masks	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# Traceback (most recent call last):
#   File "src/models/Pix2pix-CycleGAN/test.py", line 45, in <module>
#     dataset = create_dataset(opt)  # create a dataset given opt.dataset_mode and other options
#   File "/home/jupyter/eie_vision/src/models/Pix2pix-CycleGAN/data/__init__.py", line 57, in create_dataset
#     data_loader = CustomDatasetDataLoader(opt)
#   File "/home/jupyter/eie_vision/src/models/Pix2pix-CycleGAN/data/__init__.py", line 73, in __init__
#     self.dataset = dataset_class(opt)
#   File "/home/jupyter/eie_vision/src/models/Pix2pix-CycleGAN/data/single_dataset.py", line 19, in __init__
#     self.A_paths = sorted(make_dataset(opt.dataroot, opt.max_dataset_size))
#   File "/home/jupyter/eie_vision/src/models/Pix2pix-CycleGAN/data/image_folder.py", line 26, in make_dataset
#     assert os.path.isdir(dir), '%s is not a valid directory' % dir
# AssertionError: temp/Pix2pixHD/conditional_binary_agg/test_latest/ is not a valid directory

# %% [markdown]
# ### Now we copy our generated images into the right ./Results/. directory

# %%
! cd ../.. ; mkdir results/Pix2pixHD/conditional_binary_agg/ ; cp -R temp/Pix2pixHD/conditional_binary_agg/test_latest/images/* results/Pix2pixHD/conditional_binary_agg/ ; cp -R temp/Pix2pixHD/conditional_binary_agg_masks/to_segment_latest/images/*image_fake_B.png results/Pix2pixHD/conditional_binary_agg/
# Out:
# cp: cannot stat 'temp/Pix2pixHD/conditional_binary_agg/test_latest/images/*': No such file or directory
# cp: cannot stat 'temp/Pix2pixHD/conditional_binary_agg_masks/to_segment_latest/images/*image_fake_B.png': No such file or directory
